# %%
import pandas as pd

# Read the CSV files
df1 = pd.read_csv('files_for_lab/file1.csv')
df2 = pd.read_csv('files_for_lab/file2.csv')
df3 = pd.read_csv('files_for_lab/file3.csv')
print("Shape of DataFrame 1:", df1.shape)
print("Shape of DataFrame 2:", df2.shape)
print("Shape of DataFrame 3:", df3.shape)
def standardize_headers(df):
    df.columns = df.columns.str.strip().str.lower().str.replace(' ', '_').str.replace('(', '').str.replace(')', '')
    return df

df1 = standardize_headers(df1)
df2 = standardize_headers(df2)
df3 = standardize_headers(df3)
df = pd.concat([df1, df2, df3], ignore_index=True)
numerical_cols = df.select_dtypes(include=['number']).columns.tolist()
categorical_cols = df.select_dtypes(include=['object']).columns.tolist()

print("Numerical columns:", numerical_cols)
print("Categorical columns:", categorical_cols)
df.drop(columns=['education', 'number_of_open_complaints'], inplace=True)
df['customer_lifetime_value'] = df['customer_lifetime_value'].str.replace('%', '').astype(float) * 100
df.drop_duplicates(inplace=True)
df = df[df['income'] > 0]
import pandas as pd

# Read the CSV files
df1 = pd.read_csv('files_for_lab/file1.csv')
df2 = pd.read_csv('files_for_lab/file2.csv')
df3 = pd.read_csv('files_for_lab/file3.csv')

# Standardize header names
def standardize_headers(df):
    df.columns = df.columns.str.strip().str.lower().str.replace(' ', '_').str.replace('(', '').str.replace(')', '')
    return df

df1 = standardize_headers(df1)
df2 = standardize_headers(df2)
df3 = standardize_headers(df3)

# Concatenate the DataFrames
df = pd.concat([df1, df2, df3], ignore_index=True)

# Identifying numerical and categorical columns
numerical_cols = df.select_dtypes(include=['number']).columns.tolist()
categorical_cols = df.select_dtypes(include=['object']).columns.tolist()

# Delete specific columns
df.drop(columns=['education', 'number_of_open_complaints'], inplace=True)

# Correct the values in the column `customer_lifetime_value`
df['customer_lifetime_value'] = df['customer_lifetime_value'].str.replace('%', '').astype(float) * 100

# Check for duplicate rows and remove them
df.drop_duplicates(inplace=True)

# Filter out data for customers with income of 0 or less
df = df[df['income'] > 0]

# Output the cleaned DataFrame
print(df.head())
